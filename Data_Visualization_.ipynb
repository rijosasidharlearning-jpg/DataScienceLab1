# %% [markdown]
# <a href="https://colab.research.google.com/github/rijosasidharlearning-jpg/DataScienceLab1/blob/main/Data_Visualization_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization using Python
#
# ## MathPlotLib
#   #### Basic lib for math operations to visualization.
#   #### Not asthetic.
#    #### More lines of code required for better visualization
#   #### aggaregation/computation seperately
#
# ## Seaborn
#   #### Built on top of MathplotLib
#   #### Asthetic
#   #### Less code
#   #### aggregation/computation is automatic
#
# ## Plotty
#   #### Interactive

# %% [markdown]
# # Data Analysis - Getting Insights from data
# #### can use statitics and different visualization tools
#
# # Types of Atrributes of data
#
# ### Numerical  -  Integeres, real numbers {Quantitative Variables}
#
# ### Categorical - Colors, Gender , Vehicles, Polls , Ratings etc  {Qualitative variables}
#
# ### This is important because accordingly we need to use plots/ graphs
#
#
#
#
# ## Types of analysis
#
# ### Univariate Analysis - 1 variable at a time
# ### Bivariate Analysis - 2 variables  together
# ### Multivariate Analysis - >2  variables simultaneosly

# %% [markdown]
# # Graphs or plots used for different analysis types - 1 variable
#
# ## **1 variable**
#
# ### **Numeric**
#
# #### 1. **Histogram** (x = values, y axis = frequencies  with bars/bucktes) . Its used for frquencey distribution
#
# #### 2. **Distribution/ Density Plot**
# #### (Kde) . It shows curve of distribution
#
# #### 3. **Box Plot** Can also use for multiple
# #### To detect the extreme outliers. Extreme values in a dataset(Anomalies). Outside Q1 and Q2 lies anomalies
#
# #### Q1 - Min Range - Q1 - 1.5 +IQR
# #### Q2 - 25%
# #### Median - 50%
# #### Q2 -75%
# #### Q3 - Max Range - Q3 +1.5 %
#
# ### **Categorical**
#
# #### 1. **PieChart**
#
# #### 2. **Count Plot**

# %% [markdown]
# # Graphs or plots used for different analysis types - 2 variables
#
# ## **2 variables**
#
# #### **-> Both Numeric**
# #### 1. Scatter Plot
#
# #### **-> 1 Numeric and 1 Category**
#
# #### 1. Bar Graph (ex- Cities on x axis , population on y axis)
#
# #### 2. Box Plot
#
# #### **-> 1 Numeric and 1 Time Line**
#
# #### 1. Line Graph or Trend Graph

# %% [markdown]
# # Graphs or plots used for different analysis types - 3 variables
# ## **3 variables**
#
# ### **All are Numeric**
#
# #### 1. **Corelation HeatMap**
